# %% [markdown]
# # Capstone 2 - Project
#
# ### aVpR
#
# How the variation in the last 10 years of World Championships in Track and Field - 100 meters race could explain improvements (successful training program - or - doping | other reasons) in performance of athletic performance?

# %% [markdown]
# ## Contents
#
# * [1 Data Collection](#1_Data_Collection)
#   * [1.1 Data Loading](#1.1_Data_load)
#   * [1.2 Data Joining](#1.2_Data_join)
# * [2 Data Definition](#2_Data_Definition)
#   * [2.1 Contents](#2.1_Contents)
#   * [2.2 Introduction](#2.2_Introduction)
# * [3 Data Cleaning](#3_Data_Cleaning)
#   * [3.1 Contents](#3.1_Contents)
#   * [3.2 Introduction](#3.2_Introduction)

# %% [markdown]
# ## 1. Data Collection<a id='1_Data_Collection'></a>

# %%
# Import pandas
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ### 1.1. Data Loading<a id='1.1_Data_load'></a>

# %%
# List of World Championships
athletic_url = 'https://en.wikipedia.org/wiki/World_Athletics_Championships'
athletic_res = pd.read_html(athletic_url)

# %%
# DataFrame of World Championships
World_IAAF = pd.DataFrame(athletic_res[1])
World_IAAF
# Out:
#    Edition  Year        City         Country                Date  \
# 0        –  1976       Malmö          Sweden              18 Sep
# 1        –  1980     Sittard     Netherlands         14 – 16 Aug
# 2      1st  1983    Helsinki         Finland          7 – 14 Aug
# 3      2nd  1987        Rome           Italy      28 Aug – 6 Sep
# 4      3rd  1991       Tokyo           Japan      23 Aug – 1 Sep
# 5      4th  1993   Stuttgart         Germany         13 – 22 Aug
# 6      5th  1995  Gothenburg          Sweden          5 – 13 Aug
# 7      6th  1997      Athens          Greece          1 – 10 Aug
# 8      7th  1999     Seville           Spain         20 – 29 Aug
# 9      8th  2001    Edmonton          Canada          3 – 12 Aug
# 10     9th  2003       Paris          France         23 – 31 Aug
# 11    10th  2005    Helsinki         Finland          6 – 14 Aug
# 12    11th  2007       Osaka           Japan      24 Aug – 2 Sep
# 13    12th  2009      Berlin         Germany         15 – 23 Aug
# 14    13th  2011       Daegu     South Korea      27 Aug – 4 Sep
# 15    14th  2013      Moscow          Russia         10 – 18 Aug
# 16    15th  2015     Beijing           China         22 – 30 Aug
# 17    16th  2017      London  United Kingdom          4 – 13 Aug
# 18    17th  2019        Doha           Qatar      27 Sep – 6 Oct
# 19    18th  2022      Eugene   United States  15 – 24 July[6][7]
# 20    19th  2023    Budapest         Hungary         18 – 27 Aug
#
#                             Venue  Capacity  Events  Nations  Athletes  \
# 0                   Malmö Stadion     30000     1.0     20.0      42.0
# 1                     De Baandert     22000     2.0     21.0      42.0
# 2                  Olympiastadion     50000    41.0    153.0    1333.0
# 3                 Stadio Olimpico     60000    43.0    156.0    1419.0
# 4                 Olympic Stadium     48000    43.0    162.0    1491.0
# 5        Gottlieb-Daimler-Stadion     70000    44.0    187.0    1630.0
# 6                          Ullevi     42000    44.0    190.0    1755.0
# 7                Olympiako Stadio     75000    44.0    197.0    1785.0
# 8                Estadio Olímpico     70000    46.0    200.0    1750.0
# 9            Commonwealth Stadium     60000    46.0    189.0    1677.0
# 10                Stade de France     78000    46.0    198.0    1679.0
# 11                 Olympiastadion     45000    47.0    191.0    1688.0
# 12                  Nagai Stadium     45000    47.0    197.0    1800.0
# 13                 Olympiastadion     74000    47.0    200.0    1895.0
# 14                  Daegu Stadium     65000    47.0    199.0    1742.0
# 15               Luzhniki Stadium     78000    47.0    203.0    1784.0
# 16       Beijing National Stadium     80000    47.0    205.0    1761.0
# 17                 London Stadium     60000    48.0    205.0    2036.0
# 18  Khalifa International Stadium     48000    49.0    206.0    1772.0
# 19                  Hayward Field     30000    49.0      NaN       NaN
# 20      National Athletics Centre     40000     NaN      NaN       NaN
#
#    Top of themedal table
# 0           Soviet Union
# 1           East Germany
# 2           East Germany
# 3           East Germany
# 4          United States
# 5          United States
# 6          United States
# 7          United States
# 8          United States
# 9                 Russia
# 10         United States
# 11         United States
# 12         United States
# 13         United States
# 14         United States
# 15         United States
# 16                 Kenya
# 17         United States
# 18         United States
# 19                   NaN
# 20                   NaN

# %% [markdown]
# ### Results 100m Race from 2009 (Berlin) to 2019 (Doha)

# %% [markdown]
# ### 1.2. Data Joining<a id='1.2_Data_join'></a>
#
# Data found in different requests will be concat

# %%
# Set index =  Year
World_IAAF.index = World_IAAF['Year']

# %%
# URL info
# World Championships to read data
World_IAAF['url'] = np.NaN

# Set url for WC from 2009 to 2019
{2019:'iaaf-world-athletics-championships-doha-2019-7125365',
 2017}



# Una linea asignacion
World_IAAF.loc[World_IAAF['Year'] == 2019, 'url'] = 'iaaf-world-athletics-championships-doha-2019-7125365'
World_IAAF.loc[World_IAAF['Year'] == 2017, 'url'] = 'iaaf-world-championships-london-2017-7093740'
World_IAAF.loc[World_IAAF['Year'] == 2015, 'url'] = '15th-iaaf-world-championships-7078726'
World_IAAF.loc[World_IAAF['Year'] == 2013, 'url'] = '14th-iaaf-world-championships-7003368'
World_IAAF.loc[World_IAAF['Year'] == 2011, 'url'] = '13th-iaaf-world-championships-in-athletics-7003367'
World_IAAF.loc[World_IAAF['Year'] == 2009, 'url'] = '12th-iaaf-world-championships-in-athletics-6998524'

# %%
# Check the Index of WC
World_IAAF.index
# Out:
# Int64Index([1976, 1980, 1983, 1987, 1991, 1993, 1995, 1997, 1999, 2001, 2003,
#             2005, 2007, 2009, 2011, 2013, 2015, 2017, 2019, 2022, 2023],
#            dtype='int64', name='Year')

# %%
# Init part of url
url_init = 'https://worldathletics.org/competitions/world-athletics-championships/'
# Last URL part
url_last = 'results/men/100-metres/ROUND/summary'

# semi-final from 2011, quarter-final in 2009
# af_2009 = ['heats', 'quarter-final', 'semi-final', 'final']
# quarter final was showing an error 
af_2009 = ['heats', 'semi-final', 'final']
bf_2009 = ['preliminary-round', 'heats', 'semi-final', 'final']

# %%
# Building the url for the data that we will gather

# Only WC with url data
wc_auxurl = pd.notnull(World_IAAF['url'])
wc_url = World_IAAF[['url','Year']][wc_auxurl]

# %%
# Checking URL to call --> wc_url
list_urlwc = wc_url.values.tolist()

# %%
year_wc = []
all_wc = []
round_wc = []

for url_row in list_urlwc:
    # Validate year of WC
    if url_row[1] <= 2009:
        for round in af_2009:
            call_url = url_init + url_row[0] +'/' + url_last.replace('ROUND',round)
            year_wc.append(url_row[1])
            all_wc.append(call_url)
            round_wc.append(round)
    else:    
        for round in bf_2009:
            call_url = url_init + url_row[0] +'/' + url_last.replace('ROUND',round)
            year_wc.append(url_row[1])
            all_wc.append(call_url)
            round_wc.append(round)

# %%
# Review URL
# all_wc
# year_wc
# round_wc
d = {'wc_url': all_wc,'year_wc':year_wc, 'round_wc':round_wc}
data = pd.DataFrame(d)
data
# Out:
#                                                wc_url  year_wc  \
# 0   https://worldathletics.org/competitions/world-...     2009
# 1   https://worldathletics.org/competitions/world-...     2009
# 2   https://worldathletics.org/competitions/world-...     2009
# 3   https://worldathletics.org/competitions/world-...     2011
# 4   https://worldathletics.org/competitions/world-...     2011
# 5   https://worldathletics.org/competitions/world-...     2011
# 6   https://worldathletics.org/competitions/world-...     2011
# 7   https://worldathletics.org/competitions/world-...     2013
# 8   https://worldathletics.org/competitions/world-...     2013
# 9   https://worldathletics.org/competitions/world-...     2013
# 10  https://worldathletics.org/competitions/world-...     2013
# 11  https://worldathletics.org/competitions/world-...     2015
# 12  https://worldathletics.org/competitions/world-...     2015
# 13  https://worldathletics.org/competitions/world-...     2015
# 14  https://worldathletics.org/competitions/world-...     2015
# 15  https://worldathletics.org/competitions/world-...     2017
# 16  https://worldathletics.org/competitions/world-...     2017
# 17  https://worldathletics.org/competitions/world-...     2017
# 18  https://worldathletics.org/competitions/world-...     2017
# 19  https://worldathletics.org/competitions/world-...     2019
# 20  https://worldathletics.org/competitions/world-...     2019
# 21  https://worldathletics.org/competitions/world-...     2019
# 22  https://worldathletics.org/competitions/world-...     2019
#
#              round_wc
# 0               heats
# 1          semi-final
# 2               final
# 3   preliminary-round
# 4               heats
# 5          semi-final
# 6               final
# 7   preliminary-round
# 8               heats
# 9          semi-final
# 10              final
# 11  preliminary-round
# 12              heats
# 13         semi-final
# 14              final
# 15  preliminary-round
# 16              heats
# 17         semi-final
# 18              final
# 19  preliminary-round
# 20              heats
# 21         semi-final
# 22              final

# %% [markdown]
# ### Note:
#
# Will be important to have the Exact Date, Time, and Wind of the Race.
# Must have manually take from HTML or maybe read by request.
#
# #### Example:
# Preliminary round, Doha 2019:
#
# - Heat 1 27 SEP 2019 16:35 Wind +0.1
# - Heat 2 27 SEP 2019 16:43 Wind +0.4
# - Heat 3 27 SEP 2019 16:51 Wind +0.3
# - Heat 4 27 SEP 2019 16:59 Wind 0.0
#
# Heats, Doha 2019:
#
# - Heat 1 27 SEP 2019 18:05 Wind -0.3
# - Heat 2 27 SEP 2019 18:13 Wind -0.8
# - Heat 3 27 SEP 2019 18:21 Wind -0.8
#
# Semi-final, Doha 2019:
#
# - Heat 1 28 SEP 2019 18:45 Wind -0.3
# - Heat 2 28 SEP 2019 18:53 Wind -0.1
# - Heat 3 28 SEP 2019 19:01 Wind +0.8
#
# Final, Doha 2019:
#
# - 8 SEP 2019 22:15 Wind +0.6
#
# Manual info about race: Date, Time, Wind: columns = ['Year','Heat','Date','Time','Wind']

# %%
finals_wc = data['round_wc'] == 'final'

# %%
# With all links set, we start to download the info
# Only Finals - Info was changed in the WebPage
df_finals = pd.DataFrame()

for idx, url_row in data[finals_wc].iterrows():
        #track_res = pd.read_html(url_row['wc_url'])            
        print(url_row['wc_url'])
        # wait 3 seconds to request again
        #time.sleep(3)
# Out:
# https://worldathletics.org/competitions/world-athletics-championships/12th-iaaf-world-championships-in-athletics-6998524/results/men/100-metres/final/summary
# https://worldathletics.org/competitions/world-athletics-championships/13th-iaaf-world-championships-in-athletics-7003367/results/men/100-metres/final/summary
# https://worldathletics.org/competitions/world-athletics-championships/14th-iaaf-world-championships-7003368/results/men/100-metres/final/summary
# https://worldathletics.org/competitions/world-athletics-championships/15th-iaaf-world-championships-7078726/results/men/100-metres/final/summary
# https://worldathletics.org/competitions/world-athletics-championships/iaaf-world-championships-london-2017-7093740/results/men/100-metres/final/summary
# https://worldathletics.org/competitions/world-athletics-championships/iaaf-world-athletics-championships-doha-2019-7125365/results/men/100-metres/final/summary

# %%
# Example:
track_url = 'https://worldathletics.org/competitions/world-athletics-championships/12th-iaaf-world-championships-in-athletics-6998524/results/men/100-metres/final/summary'
track_res = pd.read_html(track_url)

x0 = track_res[0]
x0['year'] = 2009

# %%
# Example:
track_url = 'https://worldathletics.org/competitions/world-athletics-championships/13th-iaaf-world-championships-in-athletics-7003367/results/men/100-metres/final/summary'
track_res = pd.read_html(track_url)

x1 = track_res[0]
x1['year'] = 2011

# %%
# Example:
track_url = 'https://worldathletics.org/competitions/world-athletics-championships/15th-iaaf-world-championships-7078726/results/men/100-metres/final/summary'
track_res = pd.read_html(track_url)

x2 = track_res[0]
x2['year'] = 2013

# %%
# Example:
track_url = 'https://worldathletics.org/competitions/world-athletics-championships/14th-iaaf-world-championships-7003368/results/men/100-metres/final/summary'
track_res = pd.read_html(track_url)

x3 = track_res[0]
x3['year'] = 2015

# %%
track_url = 'https://worldathletics.org/competitions/world-athletics-championships/iaaf-world-championships-london-2017-7093740/results/men/100-metres/final/summary'
track_res = pd.read_html(track_url)

x4 = track_res[0]
x4['year'] = 2017

# %%
track_url = 'https://worldathletics.org/competitions/world-athletics-championships/iaaf-world-athletics-championships-doha-2019-7125365/results/men/100-metres/final/summary'
track_res = pd.read_html(track_url)

x5 = track_res[0]
x5['year'] = 2019

# %%
x1['year'] = 2011
x2['year'] = 2013
x3['year'] = 2015
x4['year'] = 2017
x5['year'] = 2019

# %%
df_finals = pd.DataFrame()

df_finals = pd.concat([x0, x1, x2, x3, x4, x5])

df_finals.reset_index(inplace=True)

# %%
#
df_finals.sort_values(by=['Reaction Time'])
#df_finals
# Out:
#     index  Pos   Bib Country              Athlete      Mark  Reaction Time  \
# 15      7  NaN   588     JAM           Usain Bolt        DQ         -0.104
# 44      3  4.0  1639     RSA        Akani Simbine   9.93 SB          0.117
# 4       4  5.0  1116     TTO     Richard Thompson   9.93 SB          0.119
# 46      5  6.0   841     GBR       Zharnel Hughes     10.03          0.119
# 5       5  6.0   492     GBR       Dwain Chambers  10.00 SB          0.123
# 34      1  2.0  1386     USA    Christian Coleman      9.94          0.123
# 21      5  6.0  1018     USA            Tyson Gay     10.00          0.128
# 41      0  1.0  1876     USA    Christian Coleman   9.76 WL          0.128
# 3       3  4.0   111     ANT        Daniel Bailey      9.93          0.129
# 2       2  3.0   665     JAM         Asafa Powell   9.84 SB          0.134
# 18      2  3.0   997     USA      Trayvon Bromell      9.92          0.135
# 19      3  3.0   309     CAN      Andre De Grasse   9.92 PB          0.136
# 36      3  4.0  1074     JAM          Yohan Blake      9.99          0.137
# 33      0  1.0  1395     USA        Justin Gatlin   9.92 SB          0.138
# 20      4  5.0  1054     USA         Mike Rodgers      9.94          0.139
# 43      2  3.0   400     CAN      Andre De Grasse   9.90 PB          0.140
# 37      4  5.0  1281     RSA        Akani Simbine     10.01          0.141
# 45      4  5.0  1153     JAM          Yohan Blake      9.97          0.142
# 29      4  5.0   635     JAM      Nickel Ashmeade      9.98          0.142
# 1       1  2.0  1183     USA            Tyson Gay   9.71 NR          0.144
# 22      6  7.0   634     JAM         Asafa Powell     10.00          0.144
# 39      6  7.0   976     GBR        Reece Prescod     10.17          0.145
# 0       0  1.0   656     JAM           Usain Bolt   9.58 WR          0.146
# 42      1  2.0  1887     USA        Justin Gatlin      9.89          0.148
# 7       7  8.0  1215     USA        Darvis Patton     10.34          0.149
# 38      5  6.0   943     FRA         Jimmy Vicaut     10.08          0.152
# 14      6  7.0   589     JAM         Nesta Carter     10.95          0.154
# 31      6  7.0   452     FRA  Christophe Lemaitre     10.06          0.154
# 48      7  8.0   397     CAN          Aaron Brown     10.08          0.155
# 10      2  3.0   941     SKN          Kim Collins     10.09          0.155
# 27      2  3.0   640     JAM         Nesta Carter      9.95          0.157
# 30      5  6.0  1161     USA         Mike Rodgers     10.04          0.158
# 47      6  7.0  1106     ITA        Filippo Tortu  10.07 SB          0.158
# 16      0  1.0   620     JAM           Usain Bolt   9.79 SB          0.159
# 13      5  6.0   424     FRA         Jimmy Vicaut     10.27          0.162
# 26      1  2.0  1127     USA        Justin Gatlin   9.85 SB          0.163
# 25      0  1.0   638     JAM           Usain Bolt   9.77 SB          0.163
# 17      1  2.0  1017     USA        Justin Gatlin      9.80          0.165
# 12      4  5.0   111     ANT        Daniel Bailey     10.26          0.165
# 6       6  7.0  1110     TTO           Marc Burns  10.00 SB          0.165
# 23      7  8.0   500     FRA         Jimmy Vicaut     10.00          0.170
# 8       0  1.0   587     JAM          Yohan Blake   9.92 SB          0.174
# 9       1  2.0  1073     USA           Walter Dix     10.08          0.175
# 24      8  9.0   338     CHN          Bingtian Su     10.06          0.175
# 32      7  8.0   480     GBR        James Dasaolu     10.21          0.177
# 11      3  4.0   413     FRA  Christophe Lemaitre     10.19          0.179
# 35      2  3.0  1075     JAM           Usain Bolt   9.95 SB          0.183
# 28      3  4.0   636     JAM    Kemar Bailey-Cole      9.98          0.186
# 40      7  8.0   778     CHN          Bingtian Su     10.27          0.224
#
#     year
# 15  2011
# 44  2019
# 4   2009
# 46  2019
# 5   2009
# 34  2017
# 21  2013
# 41  2019
# 3   2009
# 2   2009
# 18  2013
# 19  2013
# 36  2017
# 33  2017
# 20  2013
# 43  2019
# 37  2017
# 45  2019
# 29  2015
# 1   2009
# 22  2013
# 39  2017
# 0   2009
# 42  2019
# 7   2009
# 38  2017
# 14  2011
# 31  2015
# 48  2019
# 10  2011
# 27  2015
# 30  2015
# 47  2019
# 16  2013
# 13  2011
# 26  2015
# 25  2015
# 17  2013
# 12  2011
# 6   2009
# 23  2013
# 8   2011
# 9   2011
# 24  2013
# 32  2015
# 11  2011
# 35  2017
# 28  2015
# 40  2017

# %%
# Out:
#     index  Pos   Bib Country              Athlete      Mark  Reaction Time  \
# 0       0  1.0   656     JAM           Usain Bolt   9.58 WR          0.146
# 1       1  2.0  1183     USA            Tyson Gay   9.71 NR          0.144
# 2       2  3.0   665     JAM         Asafa Powell   9.84 SB          0.134
# 3       3  4.0   111     ANT        Daniel Bailey      9.93          0.129
# 4       4  5.0  1116     TTO     Richard Thompson   9.93 SB          0.119
# 5       5  6.0   492     GBR       Dwain Chambers  10.00 SB          0.123
# 6       6  7.0  1110     TTO           Marc Burns  10.00 SB          0.165
# 7       7  8.0  1215     USA        Darvis Patton     10.34          0.149
# 8       0  1.0   587     JAM          Yohan Blake   9.92 SB          0.174
# 9       1  2.0  1073     USA           Walter Dix     10.08          0.175
# 10      2  3.0   941     SKN          Kim Collins     10.09          0.155
# 11      3  4.0   413     FRA  Christophe Lemaitre     10.19          0.179
# 12      4  5.0   111     ANT        Daniel Bailey     10.26          0.165
# 13      5  6.0   424     FRA         Jimmy Vicaut     10.27          0.162
# 14      6  7.0   589     JAM         Nesta Carter     10.95          0.154
# 15      7  NaN   588     JAM           Usain Bolt        DQ         -0.104
# 16      0  1.0   620     JAM           Usain Bolt   9.79 SB          0.159
# 17      1  2.0  1017     USA        Justin Gatlin      9.80          0.165
# 18      2  3.0   997     USA      Trayvon Bromell      9.92          0.135
# 19      3  3.0   309     CAN      Andre De Grasse   9.92 PB          0.136
# 20      4  5.0  1054     USA         Mike Rodgers      9.94          0.139
# 21      5  6.0  1018     USA            Tyson Gay     10.00          0.128
# 22      6  7.0   634     JAM         Asafa Powell     10.00          0.144
# 23      7  8.0   500     FRA         Jimmy Vicaut     10.00          0.170
# 24      8  9.0   338     CHN          Bingtian Su     10.06          0.175
# 25      0  1.0   638     JAM           Usain Bolt   9.77 SB          0.163
# 26      1  2.0  1127     USA        Justin Gatlin   9.85 SB          0.163
# 27      2  3.0   640     JAM         Nesta Carter      9.95          0.157
# 28      3  4.0   636     JAM    Kemar Bailey-Cole      9.98          0.186
# 29      4  5.0   635     JAM      Nickel Ashmeade      9.98          0.142
# 30      5  6.0  1161     USA         Mike Rodgers     10.04          0.158
# 31      6  7.0   452     FRA  Christophe Lemaitre     10.06          0.154
# 32      7  8.0   480     GBR        James Dasaolu     10.21          0.177
# 33      0  1.0  1395     USA        Justin Gatlin   9.92 SB          0.138
# 34      1  2.0  1386     USA    Christian Coleman      9.94          0.123
# 35      2  3.0  1075     JAM           Usain Bolt   9.95 SB          0.183
# 36      3  4.0  1074     JAM          Yohan Blake      9.99          0.137
# 37      4  5.0  1281     RSA        Akani Simbine     10.01          0.141
# 38      5  6.0   943     FRA         Jimmy Vicaut     10.08          0.152
# 39      6  7.0   976     GBR        Reece Prescod     10.17          0.145
# 40      7  8.0   778     CHN          Bingtian Su     10.27          0.224
# 41      0  1.0  1876     USA    Christian Coleman   9.76 WL          0.128
# 42      1  2.0  1887     USA        Justin Gatlin      9.89          0.148
# 43      2  3.0   400     CAN      Andre De Grasse   9.90 PB          0.140
# 44      3  4.0  1639     RSA        Akani Simbine   9.93 SB          0.117
# 45      4  5.0  1153     JAM          Yohan Blake      9.97          0.142
# 46      5  6.0   841     GBR       Zharnel Hughes     10.03          0.119
# 47      6  7.0  1106     ITA        Filippo Tortu  10.07 SB          0.158
# 48      7  8.0   397     CAN          Aaron Brown     10.08          0.155
#
#     year
# 0   2009
# 1   2009
# 2   2009
# 3   2009
# 4   2009
# 5   2009
# 6   2009
# 7   2009
# 8   2011
# 9   2011
# 10  2011
# 11  2011
# 12  2011
# 13  2011
# 14  2011
# 15  2011
# 16  2013
# 17  2013
# 18  2013
# 19  2013
# 20  2013
# 21  2013
# 22  2013
# 23  2013
# 24  2013
# 25  2015
# 26  2015
# 27  2015
# 28  2015
# 29  2015
# 30  2015
# 31  2015
# 32  2015
# 33  2017
# 34  2017
# 35  2017
# 36  2017
# 37  2017
# 38  2017
# 39  2017
# 40  2017
# 41  2019
# 42  2019
# 43  2019
# 44  2019
# 45  2019
# 46  2019
# 47  2019
# 48  2019

# %%
# # Number of Heats in request Data
# heats_number = len(track_res)

# # Iterate to save the data
# heats_number
# track_res[0]
# Out:
#    Pos   Bib Country            Athlete      Mark  Reaction Time
# 0    1  1876     USA  Christian Coleman   9.76 WL          0.128
# 1    2  1887     USA      Justin Gatlin      9.89          0.148
# 2    3   400     CAN    Andre De Grasse   9.90 PB          0.140
# 3    4  1639     RSA      Akani Simbine   9.93 SB          0.117
# 4    5  1153     JAM        Yohan Blake      9.97          0.142
# 5    6   841     GBR     Zharnel Hughes     10.03          0.119
# 6    7  1106     ITA      Filippo Tortu  10.07 SB          0.158
# 7    8   397     CAN        Aaron Brown     10.08          0.155

# %% [markdown]
# ## 2. Data Definition<a id='2_Data_Definition'></a>
#
# <p><strong>Data Definition</strong></p>
# <ul>
# <li>Column names</li>
# <li>Data types</li>
# <li>Description of the columns</li>
# <li>Counts and percents unique values</li>
# <li>Ranges of values</li>
# </ul>
# <p style="padding-left: 30px;">- Hint: here are some useful questions to ask yourself during this process:
#     - Do your column names correspond to what those columns store?
#    - Check the data types of your columns. Are they sensible?<br />- Calculate summary statistics for each of your columns, such<br />as mean, median, mode, standard deviation, range, and<br />number of unique values. What does this tell you about your<br />data? What do you now need to investigate?</p>

# %% [markdown]
# ## 3. Data Cleaning<a id='3_Data_Cleaning'></a>
# <p><strong>Data Cleaning</strong></p>
# <ul>
# <li>NA or missing values</li>
# <li>Duplicates</li>
# </ul>
# <p>- Hint: don&rsquo;t forget about the following awesome Python functions for data<br />cleaning, which make life a whole lot easier:<br />- loc[] - filter your data by label<br />- iloc[] - filter your data by indexes<br />- apply() - execute a function across an axis of a DataFrame<br />- drop() - drop columns from a DataFrame<br />- is_unique() - check if a column is a unique identifier<br />- Series methods, such as str.contains(), which can be used to check if<br />a certain substring occurs in a string of a Series, and str.extract(),<br />which can be used to extract capture groups with a certain regex (or<br />regular expression ) pattern<br />- numPy methods like .where(), to clean columns. Recall that such<br />methods have the structure: np.where(condition, then, else)<br />-DataFrame methods to check for null values, such as df.isnull().values.any()</p>
